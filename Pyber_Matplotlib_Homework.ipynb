# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
Left = pd.read_csv(city_data_to_load)
Right = pd.read_csv(ride_data_to_load)
# Combine the data into a single dataset
Data = ride_df.merge(city_df, 'inner')
# Display the data table for preview
Data = Data[['city', 'date', 'fare', 'ride_id', 'driver_count', 'type']]
Data.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  Lake Jonathanshire  2018-04-07 20:51:11  31.25  4441251834598
# 2  Lake Jonathanshire  2018-03-09 23:45:55  19.89  2389495660448
# 3  Lake Jonathanshire  2018-04-07 18:09:21  24.28  7796805191168
# 4  Lake Jonathanshire  2018-01-02 14:14:50  13.89   424254840012
#
#    driver_count   type
# 0             5  Urban
# 1             5  Urban
# 2             5  Urban
# 3             5  Urban
# 4             5  Urban

# %%
urban1 = (Data[Data['type'] == "Urban"])
urban1.reset_index(drop=True)
#urban1 = urban1.drop(['ride_id'], axis=1)
urban1 = urban1.groupby('city').count()
urban1 = urban1.round(2)

# %%
urban = (Data[Data['type'] == "Urban"])
urban.reset_index(drop=True)
urban = urban.drop(['ride_id'], axis=1)
urban = urban.groupby('city').mean()
urban['Ride Count'] = urban1['ride_id']
urban = urban.round(2)
urban
# Out:
#                        fare  driver_count  Ride Count
# city
# Amandaburgh           24.64            12          18
# Barajasview           25.33            26          22
# Carriemouth           28.31            52          27
# Christopherfurt       24.50            41          27
# Deanville             25.84            49          19
# East Kaylahaven       23.76            65          29
# Erikaland             24.91            37          12
# Grahamburgh           25.22            61          25
# Huntermouth           28.99            37          24
# Hurleymouth           25.89            36          28
# Jerryton              25.65            64          25
# Johnton               26.79            27          21
# Joneschester          22.29            39          25
# Justinberg            23.69            39          30
# Karenberg             26.34            22          17
# Karenside             27.45             5          28
# ...

# %%
suburban1 = (Data[Data['type'] == "Suburban"])
suburban1.reset_index(drop=True)
#suburban1 = suburban1.drop(['ride_id'], axis=1)
suburban1 = suburban1.groupby('city').count()
suburban1 = suburban1.round(2)

# %%
suburban = (Data[Data['type'] == "Suburban"])
suburban.reset_index(drop=True)
suburban = suburban.drop(['ride_id'], axis=1)
suburban = suburban.groupby('city').mean()
suburban['Ride Count'] = suburban1['ride_id']
suburban = suburban.round(2)
suburban
# Out:
#                      fare  driver_count  Ride Count
# city
# Barronchester       36.42            11          16
# Bethanyland         32.96            22          18
# Brandonfort         35.44            10          19
# Colemanland         30.89            23          22
# Davidfurt           32.00            23          17
# East Aaronbury      25.66             7           9
# East Danielview     31.56            22          17
# East Kentstad       29.82            20          13
# East Marymouth      30.84             5          27
# Grayville           27.76             2          15
# Josephside          32.86            25          27
# Lake Ann            30.89             3          12
# Lake Omar           28.07            22          14
# Lake Robertside     31.26             4          25
# Lake Scott          31.89            23          18
# Lewishaven          25.24            23          12
# Lewisland           34.61             4          17
# ...

# %%
rural1 = (Data[Data['type'] == "Rural"])
rural1.reset_index(drop=True)
#rural1 = rural1.drop(['ride_id'], axis=1)
rural1 = rural1.groupby('city').count()
rural1 = rural1.round(2)

# %%
rural = (Data[Data['type'] == "Rural"])
rural.reset_index(drop=True)
rural = rural.drop(['ride_id'], axis=1)
rural = rural.groupby('city').mean()
rural['Ride Count'] = rural1['ride_id']
rural = rural.round(2)
rural
# Out:
#                     fare  driver_count  Ride Count
# city
# Bradshawfurt       40.06             7          10
# Garzaport          24.12             7           3
# Harringtonfort     33.47             4           6
# Jessicaport        36.01             1           6
# Lake Jamie         34.36             4           6
# Lake Latoyabury    26.06             2          11
# Michaelberg        35.00             6          12
# New Ryantown       43.28             2           6
# Newtonview         36.75             1           4
# North Holly        29.13             8           9
# North Jaime        30.80             1           8
# Penaborough        35.25             6           5
# Randallchester     29.74             9           5
# South Jennifer     35.26             7           7
# South Marychester  41.87             1           8
# South Saramouth    36.16             7           4
# Taylorhaven        42.26             1           6
# ...

# %%
x_u = urban['Ride Count']
y_u = urban['fare']
z_u = urban['driver_count']

# %%
x_s = suburban['Ride Count']
y_s = suburban['fare']
z_s = suburban['driver_count']

# %%
x_r = rural['Ride Count']
y_r = rural['fare']
z_r = rural['driver_count']

# %%
plt.scatter(x_u, y_u, s=z_u*10, color = "coral", linewidth=1, alpha=0.8, edgecolors="black", label='Urban')
plt.scatter(x_s, y_s, s=z_s*10, color = "lightskyblue", linewidth=1, alpha=0.8, edgecolors="black", label='Suburban')
plt.scatter(x_r, y_r, s=z_r*10, color = "gold", linewidth=1, alpha=0.8, edgecolors="black", label='Rural')
plt.xlabel("Total Number of Rides (per city)")
plt.ylabel("Average Fair ($)")
plt.title("Pyber Ride Sharing Data (2016)")
plt.legend(loc='upper right')
plt.grid(b=None, which='major', axis='both')
plt.text(42, 40, "Note: ")
plt.text(42, 38, "Circle size correlates with driver count per city.")
plt.show()

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types

# Build the scatter plots for each city types

# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents

# Build Pie Charts

# Save Figure

# %%
# Show Figure
plt.show()
