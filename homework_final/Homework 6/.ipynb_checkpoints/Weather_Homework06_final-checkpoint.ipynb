# %%
# %matplotlib notebook

# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
import json

# Import API key
from api_keys import api_key1
#print(api_key1)

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %%
city_search = [] 
for city in cities:
    names = city.split()
    city_searchable = '+'.join(names)
    city_search.append(city_searchable)
#city_search

# %%
city_index = list(range(1, (len(cities)+1)))
#print(city_index)

# %%
name =[]; temp_min =[]; temp_max =[]; lat =[]; lon = []; hum =[]; cloud =[]; wind =[]; response_json = []; dt = []; country =[]

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
print("Beginning Data Retrieval")
print("-----------------------------------------------")
for city in city_search:
    try:
        target_url = base_url + "APPID=" + api_key1 + "&q=" + str(city_search[city_search.index(city)])
        print(f"Processing record number: {(city_search.index(city)+1)} #ID: {city}")
        weather_data = requests.get(target_url).json()
        response_json.append(weather_data)
        name.append(response_json[city_search.index(city)]["name"])
        temp_min.append(response_json[city_search.index(city)]["main"]["temp_min"])
        temp_max.append(response_json[city_search.index(city)]["main"]["temp_max"])
        lat.append(response_json[city_search.index(city)]["coord"]["lat"])
        lon.append(response_json[city_search.index(city)]["coord"]["lon"])
        hum.append(response_json[city_search.index(city)]["main"]["humidity"])   
        cloud.append(response_json[city_search.index(city)]["clouds"]["all"])
        wind.append(response_json[city_search.index(city)]["wind"]["speed"])
        dt.append(response_json[city_search.index(city)]["dt"])
        country.append(response_json[city_search.index(city)]["sys"]["country"])
    except (KeyError):
        print("City not found... skipping.")
# Out:
# Beginning Data Retrieval
# -----------------------------------------------
# Processing record number: 1 #ID: taolanaro
# City not found... skipping.
# Processing record number: 2 #ID: thompson
# Processing record number: 3 #ID: ushuaia
# Processing record number: 4 #ID: richards+bay
# Processing record number: 5 #ID: avarua
# Processing record number: 6 #ID: souillac
# Processing record number: 7 #ID: la+ronge
# Processing record number: 8 #ID: bredasdorp
# Processing record number: 9 #ID: gobabis
# Processing record number: 10 #ID: nikolskoye
# Processing record number: 11 #ID: punta+arenas
# Processing record number: 12 #ID: krasnaya+gorka
# Processing record number: 13 #ID: hermosillo
# Processing record number: 14 #ID: port+elizabeth
# Processing record number: 15 #ID: chokurdakh
# Processing record number: 16 #ID: tessalit
# Processing record number: 17 #ID: clyde+river
# Processing record number: 18 #ID: srednekolymsk
# Processing record number: 19 #ID: rikitea
# Processing record number: 20 #ID: maarianhamina
# City not found... skipping.
# Processing record number: 21 #ID: tasiilaq
# Processing record number: 22 #ID: mataura
# Processing record number: 23 #ID: atuona
# Processing record number: 24 #ID: deniliquin
# Processing record number: 25 #ID: kruisfontein
# Processing record number: 26 #ID: torbay
# Processing record number: 27 #ID: vaini
# Processing record number: 28 #ID: port+alfred
# Processing record number: 29 #ID: cochrane
# Processing record number: 30 #ID: dalgopol
# City not found... skipping.
# Processing record number: 31 #ID: yangambi
# Processing record number: 32 #ID: new+norfolk
# Processing record number: 33 #ID: hermanus
# Processing record number: 34 #ID: mount+gambier
# Processing record number: 35 #ID: bengkulu
# City not found... skipping.
# Processing record number: 36 #ID: asfi
# City not found... skipping.
# Processing record number: 37 #ID: khatanga
# Processing record number: 38 #ID: saint-philippe
# Processing record number: 39 #ID: san+patricio
# Processing record number: 40 #ID: east+london
# Processing record number: 41 #ID: saleaula
# City not found... skipping.
# Processing record number: 42 #ID: canberra
# Processing record number: 43 #ID: harboore
# Processing record number: 44 #ID: sao+filipe
# Processing record number: 45 #ID: kodiak
# Processing record number: 46 #ID: georgetown
# Processing record number: 47 #ID: illoqqortoormiut
# City not found... skipping.
# Processing record number: 48 #ID: tsihombe
# City not found... skipping.
# Processing record number: 49 #ID: bluff
# Processing record number: 50 #ID: mayo
# Processing record number: 51 #ID: emba
# Processing record number: 52 #ID: bacolod
# Processing record number: 53 #ID: fortuna
# Processing record number: 54 #ID: carnarvon
# Processing record number: 55 #ID: dikson
# Processing record number: 56 #ID: tiksi
# Processing record number: 57 #ID: cherskiy
# Processing record number: 58 #ID: hithadhoo
# Processing record number: 59 #ID: saskylakh
# Processing record number: 60 #ID: ambilobe
# Processing record number: 61 #ID: chuka
# Processing record number: 62 #ID: the+valley
# Processing record number: 63 #ID: umzimvubu
# City not found... skipping.
# Processing record number: 64 #ID: san+carlos+de+bariloche
# Processing record number: 65 #ID: mount+isa
# Processing record number: 66 #ID: maputo
# Processing record number: 67 #ID: narsaq
# Processing record number: 68 #ID: faanui
# Processing record number: 69 #ID: dabakala
# Processing record number: 70 #ID: les+cayes
# Processing record number: 71 #ID: kapaa
# Processing record number: 72 #ID: cayenne
# Processing record number: 73 #ID: henties+bay
# Processing record number: 74 #ID: butaritari
# Processing record number: 75 #ID: high+level
# Processing record number: 76 #ID: albany
# Processing record number: 77 #ID: victoria
# Processing record number: 78 #ID: nizhneyansk
# City not found... skipping.
# Processing record number: 79 #ID: batagay-alyta
# Processing record number: 80 #ID: nome
# Processing record number: 81 #ID: kaeo
# Processing record number: 82 #ID: nioro
# Processing record number: 83 #ID: hilo
# Processing record number: 84 #ID: saldanha
# Processing record number: 85 #ID: aklavik
# Processing record number: 86 #ID: thai+binh
# Processing record number: 87 #ID: provideniya
# Processing record number: 88 #ID: jamestown
# Processing record number: 89 #ID: beyneu
# Processing record number: 90 #ID: havelock
# Processing record number: 91 #ID: palabuhanratu
# City not found... skipping.
# Processing record number: 92 #ID: grand+river+south+east
# City not found... skipping.
# Processing record number: 93 #ID: berlevag
# Processing record number: 94 #ID: mopti
# Processing record number: 95 #ID: barrow
# Processing record number: 96 #ID: biak
# Processing record number: 97 #ID: gafanha+da+encarnacao
# Processing record number: 98 #ID: chicama
# Processing record number: 99 #ID: teeli
# Processing record number: 100 #ID: hamilton
# Processing record number: 101 #ID: nhulunbuy
# Processing record number: 102 #ID: atar
# Processing record number: 103 #ID: nanortalik
# Processing record number: 104 #ID: tuatapere
# Processing record number: 105 #ID: ponta+do+sol
# Processing record number: 106 #ID: mitsamiouli
# Processing record number: 107 #ID: gizo
# Processing record number: 108 #ID: bakchar
# Processing record number: 109 #ID: codrington
# Processing record number: 110 #ID: cabo+san+lucas
# Processing record number: 111 #ID: ginir
# Processing record number: 112 #ID: korla
# City not found... skipping.
# Processing record number: 113 #ID: florianopolis
# Processing record number: 114 #ID: arraial+do+cabo
# Processing record number: 115 #ID: itaituba
# Processing record number: 116 #ID: padang
# Processing record number: 117 #ID: ust-kuyga
# Processing record number: 118 #ID: okhotsk
# Processing record number: 119 #ID: sentyabrskiy
# City not found... skipping.
# Processing record number: 120 #ID: paiho
# City not found... skipping.
# Processing record number: 121 #ID: komsomolskiy
# Processing record number: 122 #ID: bonavista
# Processing record number: 123 #ID: touros
# Processing record number: 124 #ID: sinyavskoye
# Processing record number: 125 #ID: marshall
# Processing record number: 126 #ID: vestmannaeyjar
# Processing record number: 127 #ID: houston
# Processing record number: 128 #ID: hami
# Processing record number: 129 #ID: amderma
# City not found... skipping.
# Processing record number: 130 #ID: camocim
# Processing record number: 131 #ID: puerto+carreno
# Processing record number: 132 #ID: yellowknife
# Processing record number: 133 #ID: belushya+guba
# City not found... skipping.
# Processing record number: 134 #ID: busselton
# Processing record number: 135 #ID: tazovskiy
# Processing record number: 136 #ID: evensk
# Processing record number: 137 #ID: puerto+ayora
# Processing record number: 138 #ID: warqla
# City not found... skipping.
# Processing record number: 139 #ID: qaanaaq
# Processing record number: 140 #ID: port+lincoln
# Processing record number: 141 #ID: tabuk
# Processing record number: 142 #ID: sisimiut
# Processing record number: 143 #ID: kamenskoye
# City not found... skipping.
# Processing record number: 144 #ID: wagga+wagga
# Processing record number: 145 #ID: vardo
# Processing record number: 146 #ID: pascagoula
# Processing record number: 147 #ID: banyo
# Processing record number: 148 #ID: kavieng
# Processing record number: 149 #ID: samusu
# City not found... skipping.
# Processing record number: 150 #ID: dalvik
# Processing record number: 151 #ID: attawapiskat
# City not found... skipping.
# Processing record number: 152 #ID: limbang
# Processing record number: 153 #ID: valparaiso
# Processing record number: 154 #ID: asau
# City not found... skipping.
# Processing record number: 155 #ID: lebu
# Processing record number: 156 #ID: marsh+harbour
# Processing record number: 157 #ID: salalah
# Processing record number: 158 #ID: peniche
# Processing record number: 159 #ID: cape+town
# Processing record number: 160 #ID: ribeira+grande
# Processing record number: 161 #ID: mar+del+plata
# Processing record number: 162 #ID: patitirion
# Processing record number: 163 #ID: saint-pierre
# Processing record number: 164 #ID: dingle
# Processing record number: 165 #ID: stamford
# Processing record number: 166 #ID: yingcheng
# Processing record number: 167 #ID: upernavik
# Processing record number: 168 #ID: bara
# Processing record number: 169 #ID: avera
# Processing record number: 170 #ID: skanderborg
# Processing record number: 171 #ID: olafsvik
# City not found... skipping.
# Processing record number: 172 #ID: mahebourg
# Processing record number: 173 #ID: barentsburg
# City not found... skipping.
# Processing record number: 174 #ID: saint-francois
# Processing record number: 175 #ID: flinders
# Processing record number: 176 #ID: samarai
# Processing record number: 177 #ID: huilong
# Processing record number: 178 #ID: redmond
# Processing record number: 179 #ID: bethel
# Processing record number: 180 #ID: yumen
# Processing record number: 181 #ID: pitimbu
# Processing record number: 182 #ID: severo-kurilsk
# Processing record number: 183 #ID: castro
# Processing record number: 184 #ID: itainopolis
# City not found... skipping.
# Processing record number: 185 #ID: rocha
# Processing record number: 186 #ID: vaitupu
# City not found... skipping.
# Processing record number: 187 #ID: hobart
# Processing record number: 188 #ID: ahumada
# City not found... skipping.
# Processing record number: 189 #ID: taksimo
# Processing record number: 190 #ID: banjar
# Processing record number: 191 #ID: tasbuget
# City not found... skipping.
# Processing record number: 192 #ID: san+luis
# Processing record number: 193 #ID: pevek
# Processing record number: 194 #ID: dinsor
# City not found... skipping.
# Processing record number: 195 #ID: ahipara
# Processing record number: 196 #ID: port+macquarie
# Processing record number: 197 #ID: tuktoyaktuk
# Processing record number: 198 #ID: longyearbyen
# Processing record number: 199 #ID: husavik
# Processing record number: 200 #ID: tanout
# Processing record number: 201 #ID: naze
# Processing record number: 202 #ID: poum
# Processing record number: 203 #ID: motril
# Processing record number: 204 #ID: sibolga
# Processing record number: 205 #ID: ballina
# Processing record number: 206 #ID: sao+jose+da+coroa+grande
# Processing record number: 207 #ID: marsaxlokk
# Processing record number: 208 #ID: jabinyanah
# Processing record number: 209 #ID: bat+khela
# Processing record number: 210 #ID: kudahuvadhoo
# Processing record number: 211 #ID: margate
# Processing record number: 212 #ID: saint-joseph
# Processing record number: 213 #ID: saint-felicien
# Processing record number: 214 #ID: eureka
# Processing record number: 215 #ID: samoded
# Processing record number: 216 #ID: lorengau
# Processing record number: 217 #ID: petropavlovsk-kamchatskiy
# Processing record number: 218 #ID: klaksvik
# Processing record number: 219 #ID: aromashevo
# Processing record number: 220 #ID: airai
# Processing record number: 221 #ID: alice+springs
# Processing record number: 222 #ID: prince+rupert
# Processing record number: 223 #ID: kaitangata
# Processing record number: 224 #ID: bonthe
# Processing record number: 225 #ID: geraldton
# Processing record number: 226 #ID: saint-claude
# Processing record number: 227 #ID: aleksandro-nevskiy
# Processing record number: 228 #ID: hofn
# Processing record number: 229 #ID: hasaki
# Processing record number: 230 #ID: mys+shmidta
# City not found... skipping.
# Processing record number: 231 #ID: znamenskoye
# Processing record number: 232 #ID: caravelas
# Processing record number: 233 #ID: maniitsoq
# Processing record number: 234 #ID: orlik
# Processing record number: 235 #ID: lata
# Processing record number: 236 #ID: darhan
# Processing record number: 237 #ID: huarmey
# Processing record number: 238 #ID: orje
# Processing record number: 239 #ID: tacuarembo
# Processing record number: 240 #ID: acarau
# City not found... skipping.
# Processing record number: 241 #ID: daru
# Processing record number: 242 #ID: san-pedro
# Processing record number: 243 #ID: gambela
# Processing record number: 244 #ID: lompoc
# Processing record number: 245 #ID: inhambane
# Processing record number: 246 #ID: luderitz
# Processing record number: 247 #ID: port+antonio
# Processing record number: 248 #ID: foki
# Processing record number: 249 #ID: sao+gabriel+da+cachoeira
# Processing record number: 250 #ID: cidreira
# Processing record number: 251 #ID: portland
# Processing record number: 252 #ID: luganville
# Processing record number: 253 #ID: salinas
# Processing record number: 254 #ID: westport
# Processing record number: 255 #ID: labuhan
# Processing record number: 256 #ID: araouane
# Processing record number: 257 #ID: lensk
# Processing record number: 258 #ID: tromso
# Processing record number: 259 #ID: kommunisticheskiy
# Processing record number: 260 #ID: nam+tha
# City not found... skipping.
# Processing record number: 261 #ID: riohacha
# Processing record number: 262 #ID: punta+cardon
# Processing record number: 263 #ID: chingirlau
# Processing record number: 264 #ID: kahului
# Processing record number: 265 #ID: tumannyy
# City not found... skipping.
# Processing record number: 266 #ID: elat
# Processing record number: 267 #ID: spydeberg
# Processing record number: 268 #ID: kazalinsk
# City not found... skipping.
# Processing record number: 269 #ID: harper
# Processing record number: 270 #ID: kulhudhuffushi
# Processing record number: 271 #ID: humaita
# Processing record number: 272 #ID: sawakin
# Processing record number: 273 #ID: mendahara
# City not found... skipping.
# Processing record number: 274 #ID: lavrentiya
# Processing record number: 275 #ID: alofi
# Processing record number: 276 #ID: durban
# Processing record number: 277 #ID: nosy+varika
# Processing record number: 278 #ID: lucea
# Processing record number: 279 #ID: nouadhibou
# Processing record number: 280 #ID: chuy
# Processing record number: 281 #ID: sambava
# Processing record number: 282 #ID: seddon
# Processing record number: 283 #ID: linda
# Processing record number: 284 #ID: mbekenyera
# Processing record number: 285 #ID: alotau
# City not found... skipping.
# Processing record number: 286 #ID: okha
# Processing record number: 287 #ID: ancud
# Processing record number: 288 #ID: ketchikan
# Processing record number: 289 #ID: dumas
# Processing record number: 290 #ID: juneau
# Processing record number: 291 #ID: george
# Processing record number: 292 #ID: doctor+pedro+p.+pena
# City not found... skipping.
# Processing record number: 293 #ID: magistralnyy
# Processing record number: 294 #ID: hervey+bay
# Processing record number: 295 #ID: carutapera
# Processing record number: 296 #ID: constitucion
# Processing record number: 297 #ID: aktau
# Processing record number: 298 #ID: kysyl-syr
# Processing record number: 299 #ID: ozgon
# City not found... skipping.
# Processing record number: 300 #ID: porto-vecchio
# Processing record number: 301 #ID: vila+velha
# Processing record number: 302 #ID: norman+wells
# Processing record number: 303 #ID: raha
# Processing record number: 304 #ID: leningradskiy
# Processing record number: 305 #ID: mikuni
# Processing record number: 306 #ID: qujing
# Processing record number: 307 #ID: wajir
# Processing record number: 308 #ID: grand-santi
# Processing record number: 309 #ID: katangli
# Processing record number: 310 #ID: chapais
# Processing record number: 311 #ID: chicla
# Processing record number: 312 #ID: pushkinskiye+gory
# Processing record number: 313 #ID: tura
# Processing record number: 314 #ID: tarudant
# City not found... skipping.
# Processing record number: 315 #ID: katsuura
# Processing record number: 316 #ID: calvinia
# Processing record number: 317 #ID: cam+ranh
# Processing record number: 318 #ID: marzuq
# Processing record number: 319 #ID: yar-sale
# Processing record number: 320 #ID: talnakh
# Processing record number: 321 #ID: wahran
# City not found... skipping.
# Processing record number: 322 #ID: kabarnet
# Processing record number: 323 #ID: novobureyskiy
# Processing record number: 324 #ID: aswan
# Processing record number: 325 #ID: lasa
# Processing record number: 326 #ID: simbahan
# Processing record number: 327 #ID: hongan
# City not found... skipping.
# Processing record number: 328 #ID: namalenga
# Processing record number: 329 #ID: englewood
# Processing record number: 330 #ID: mandera
# Processing record number: 331 #ID: isiro
# Processing record number: 332 #ID: dindigul
# Processing record number: 333 #ID: karratha
# Processing record number: 334 #ID: obo
# Processing record number: 335 #ID: linchuan
# City not found... skipping.
# Processing record number: 336 #ID: skalistyy
# City not found... skipping.
# Processing record number: 337 #ID: pangody
# Processing record number: 338 #ID: jocotitlan
# Processing record number: 339 #ID: hirado
# Processing record number: 340 #ID: honiara
# Processing record number: 341 #ID: tucuma
# City not found... skipping.
# Processing record number: 342 #ID: laguna
# Processing record number: 343 #ID: emerald
# Processing record number: 344 #ID: bambous+virieux
# Processing record number: 345 #ID: beringovskiy
# Processing record number: 346 #ID: martapura
# Processing record number: 347 #ID: kuroishi
# Processing record number: 348 #ID: machico
# Processing record number: 349 #ID: abu+dhabi
# Processing record number: 350 #ID: talah
# City not found... skipping.
# Processing record number: 351 #ID: micheweni
# Processing record number: 352 #ID: parry+sound
# Processing record number: 353 #ID: nuuk
# Processing record number: 354 #ID: waingapu
# Processing record number: 355 #ID: siocon
# Processing record number: 356 #ID: tupik
# Processing record number: 357 #ID: jinchang
# Processing record number: 358 #ID: doha
# Processing record number: 359 #ID: manzhouli
# Processing record number: 360 #ID: roswell
# Processing record number: 361 #ID: saint+george
# Processing record number: 362 #ID: wanning
# Processing record number: 363 #ID: bargal
# City not found... skipping.
# Processing record number: 364 #ID: karakendzha
# City not found... skipping.
# Processing record number: 365 #ID: hihifo
# City not found... skipping.
# Processing record number: 366 #ID: kasongo-lunda
# Processing record number: 367 #ID: heyang
# Processing record number: 368 #ID: liepaja
# Processing record number: 369 #ID: pochutla
# Processing record number: 370 #ID: mildura
# Processing record number: 371 #ID: majene
# Processing record number: 372 #ID: los+llanos+de+aridane
# Processing record number: 373 #ID: cockburn+town
# Processing record number: 374 #ID: viligili
# City not found... skipping.
# Processing record number: 375 #ID: pittsfield
# Processing record number: 376 #ID: sitka
# Processing record number: 377 #ID: rundu
# Processing record number: 378 #ID: acapulco
# Processing record number: 379 #ID: pandan
# Processing record number: 380 #ID: goderich
# Processing record number: 381 #ID: mezen
# Processing record number: 382 #ID: yala
# Processing record number: 383 #ID: lagoa
# Processing record number: 384 #ID: tonj
# City not found... skipping.
# Processing record number: 385 #ID: bubaque
# Processing record number: 386 #ID: kakonko
# Processing record number: 387 #ID: chumikan
# Processing record number: 388 #ID: bathsheba
# Processing record number: 389 #ID: antofagasta
# Processing record number: 390 #ID: esperance
# Processing record number: 391 #ID: babol
# Processing record number: 392 #ID: ilulissat
# Processing record number: 393 #ID: bahia+honda
# Processing record number: 394 #ID: jolalpan
# Processing record number: 395 #ID: dong+xoai
# Processing record number: 396 #ID: fort+nelson
# Processing record number: 397 #ID: formoso+do+araguaia
# City not found... skipping.
# Processing record number: 398 #ID: osa
# Processing record number: 399 #ID: mackenzie
# Processing record number: 400 #ID: orange+cove
# Processing record number: 401 #ID: natal
# Processing record number: 402 #ID: panuco
# Processing record number: 403 #ID: lozuvatka
# Processing record number: 404 #ID: madison
# Processing record number: 405 #ID: seoul
# Processing record number: 406 #ID: vao
# Processing record number: 407 #ID: kuusamo
# Processing record number: 408 #ID: kuche
# City not found... skipping.
# Processing record number: 409 #ID: benguela
# Processing record number: 410 #ID: hay+river
# Processing record number: 411 #ID: scalea
# Processing record number: 412 #ID: eyl
# Processing record number: 413 #ID: gazojak
# Processing record number: 414 #ID: ossora
# Processing record number: 415 #ID: ushtobe
# Processing record number: 416 #ID: kinston
# Processing record number: 417 #ID: beloye
# Processing record number: 418 #ID: havre-saint-pierre
# Processing record number: 419 #ID: gushikawa
# Processing record number: 420 #ID: vieira+de+leiria
# Processing record number: 421 #ID: anupgarh
# Processing record number: 422 #ID: tsiroanomandidy
# Processing record number: 423 #ID: sorland
# Processing record number: 424 #ID: puerto+escondido
# Processing record number: 425 #ID: los+aquijes
# Processing record number: 426 #ID: san+policarpo
# Processing record number: 427 #ID: miri
# Processing record number: 428 #ID: pacific+grove
# Processing record number: 429 #ID: kathu
# Processing record number: 430 #ID: sao+felix+do+xingu
# Processing record number: 431 #ID: buraydah
# Processing record number: 432 #ID: millinocket
# Processing record number: 433 #ID: merauke
# Processing record number: 434 #ID: pinamopoan
# Processing record number: 435 #ID: walvis+bay
# Processing record number: 436 #ID: dossor
# Processing record number: 437 #ID: abu+samrah
# Processing record number: 438 #ID: tynda
# Processing record number: 439 #ID: chiang+klang
# Processing record number: 440 #ID: atzitzintla
# Processing record number: 441 #ID: camacha
# Processing record number: 442 #ID: zhaocheng
# City not found... skipping.
# Processing record number: 443 #ID: ostrovnoy
# Processing record number: 444 #ID: san+cristobal
# Processing record number: 445 #ID: namatanai
# Processing record number: 446 #ID: guerrero+negro
# Processing record number: 447 #ID: jelenia+gora
# Processing record number: 448 #ID: tilichiki
# Processing record number: 449 #ID: inirida
# Processing record number: 450 #ID: slave+lake
# Processing record number: 451 #ID: santiago+del+estero
# Processing record number: 452 #ID: wewak
# Processing record number: 453 #ID: sandwick
# Processing record number: 454 #ID: mehamn
# Processing record number: 455 #ID: mercedes
# Processing record number: 456 #ID: leshukonskoye
# Processing record number: 457 #ID: marcona
# City not found... skipping.
# Processing record number: 458 #ID: bonfim
# Processing record number: 459 #ID: maragogi
# Processing record number: 460 #ID: othonoi
# City not found... skipping.
# Processing record number: 461 #ID: kawalu
# Processing record number: 462 #ID: tete
# Processing record number: 463 #ID: bolungarvik
# City not found... skipping.
# Processing record number: 464 #ID: saint+anthony
# Processing record number: 465 #ID: kodinsk
# Processing record number: 466 #ID: nishihara
# Processing record number: 467 #ID: jinxiang
# Processing record number: 468 #ID: kasongo
# Processing record number: 469 #ID: broome
# Processing record number: 470 #ID: khristoforovo
# City not found... skipping.
# Processing record number: 471 #ID: palana
# Processing record number: 472 #ID: ipaba
# Processing record number: 473 #ID: mandalgovi
# Processing record number: 474 #ID: nemuro
# Processing record number: 475 #ID: polazna
# Processing record number: 476 #ID: yongan
# Processing record number: 477 #ID: vila+franca+do+campo
# Processing record number: 478 #ID: coahuayana
# Processing record number: 479 #ID: chhatapur
# Processing record number: 480 #ID: beloha
# Processing record number: 481 #ID: presidente+epitacio
# Processing record number: 482 #ID: salacgriva
# Processing record number: 483 #ID: taitung
# Processing record number: 484 #ID: general+roca
# Processing record number: 485 #ID: shieli
# Processing record number: 486 #ID: smithers
# Processing record number: 487 #ID: amga
# Processing record number: 488 #ID: lavumisa
# Processing record number: 489 #ID: zaozhuang
# Processing record number: 490 #ID: tabiauea
# City not found... skipping.
# Processing record number: 491 #ID: sibu
# Processing record number: 492 #ID: tautira
# Processing record number: 493 #ID: chertkovo
# Processing record number: 494 #ID: college
# Processing record number: 495 #ID: inhumas
# Processing record number: 496 #ID: gorontalo
# Processing record number: 497 #ID: ukhta
# Processing record number: 498 #ID: kabare
# Processing record number: 499 #ID: palembang
# Processing record number: 500 #ID: astorga
# Processing record number: 501 #ID: skelleftea
# Processing record number: 502 #ID: svodin
# Processing record number: 503 #ID: porto+walter
# Processing record number: 504 #ID: saryg-sep
# Processing record number: 505 #ID: tongren
# Processing record number: 506 #ID: kamenka
# Processing record number: 507 #ID: vidim
# Processing record number: 508 #ID: haines+junction
# Processing record number: 509 #ID: doraha
# Processing record number: 510 #ID: selty
# Processing record number: 511 #ID: camaqua
# Processing record number: 512 #ID: olinda
# Processing record number: 513 #ID: guaiba
# Processing record number: 514 #ID: meulaboh
# Processing record number: 515 #ID: taiyuan
# Processing record number: 516 #ID: sofiysk
# City not found... skipping.
# Processing record number: 517 #ID: enid
# Processing record number: 518 #ID: himora
# City not found... skipping.
# Processing record number: 519 #ID: narrabri
# Processing record number: 520 #ID: chilca
# Processing record number: 521 #ID: muros
# Processing record number: 522 #ID: puerto+colombia
# Processing record number: 523 #ID: san+jose
# Processing record number: 524 #ID: rodrigues+alves
# Processing record number: 525 #ID: casper
# Processing record number: 526 #ID: niquero
# Processing record number: 527 #ID: ulladulla
# Processing record number: 528 #ID: kochubey
# Processing record number: 529 #ID: kupang
# Processing record number: 530 #ID: voznesenye
# Processing record number: 531 #ID: winnemucca
# Processing record number: 532 #ID: phan+rang
# City not found... skipping.
# Processing record number: 533 #ID: rungata
# City not found... skipping.
# Processing record number: 534 #ID: plettenberg+bay
# Processing record number: 535 #ID: jibuti
# City not found... skipping.
# Processing record number: 536 #ID: lebyazhye
# Processing record number: 537 #ID: huinan
# Processing record number: 538 #ID: mahajanga
# Processing record number: 539 #ID: pontianak
# Processing record number: 540 #ID: port+shepstone
# Processing record number: 541 #ID: marsa+matruh
# Processing record number: 542 #ID: olga
# Processing record number: 543 #ID: son+la
# Processing record number: 544 #ID: valleyview
# Processing record number: 545 #ID: vilyuysk
# Processing record number: 546 #ID: teacapan
# Processing record number: 547 #ID: port+hardy
# Processing record number: 548 #ID: baykit
# Processing record number: 549 #ID: pisco
# Processing record number: 550 #ID: kavaratti
# Processing record number: 551 #ID: grand+centre
# City not found... skipping.
# Processing record number: 552 #ID: yaritagua
# Processing record number: 553 #ID: kutum
# Processing record number: 554 #ID: leh
# Processing record number: 555 #ID: kanzaki
# Processing record number: 556 #ID: colonial+heights
# Processing record number: 557 #ID: port+blair
# Processing record number: 558 #ID: sao+joao+da+barra
# Processing record number: 559 #ID: kaseda
# Processing record number: 560 #ID: marfino
# Processing record number: 561 #ID: shitanjing
# Processing record number: 562 #ID: tungkang
# City not found... skipping.
# Processing record number: 563 #ID: carballo
# Processing record number: 564 #ID: ust-tsilma
# Processing record number: 565 #ID: igarka
# Processing record number: 566 #ID: severnoye
# Processing record number: 567 #ID: udachnyy
# Processing record number: 568 #ID: aksarka
# Processing record number: 569 #ID: haverfordwest
# Processing record number: 570 #ID: aginskoye
# Processing record number: 571 #ID: ridgecrest
# Processing record number: 572 #ID: ilebo
# Processing record number: 573 #ID: lisala
# Processing record number: 574 #ID: pontes+e+lacerda
# Processing record number: 575 #ID: vostok
# Processing record number: 576 #ID: moshenskoye
# Processing record number: 577 #ID: mahenge
# Processing record number: 578 #ID: tikrit
# Processing record number: 579 #ID: camabatela
# Processing record number: 580 #ID: cap+malheureux
# Processing record number: 581 #ID: huancavelica
# Processing record number: 582 #ID: salinopolis
# Processing record number: 583 #ID: sarh
# Processing record number: 584 #ID: marienburg
# Processing record number: 585 #ID: chagda
# City not found... skipping.
# Processing record number: 586 #ID: ponta+delgada
# Processing record number: 587 #ID: jhunjhunun
# Processing record number: 588 #ID: itambacuri
# Processing record number: 589 #ID: klyuchi
# Processing record number: 590 #ID: puerto+del+rosario
# Processing record number: 591 #ID: phuket
# Processing record number: 592 #ID: pafos
# City not found... skipping.
# Processing record number: 593 #ID: ye
# City not found... skipping.
# Processing record number: 594 #ID: charters+towers
# Processing record number: 595 #ID: tabou
# Processing record number: 596 #ID: yeppoon
# Processing record number: 597 #ID: palanga
# Processing record number: 598 #ID: kaiserslautern
# Processing record number: 599 #ID: nayoro
# Processing record number: 600 #ID: rio+gallegos
# Processing record number: 601 #ID: la+tuque
# Processing record number: 602 #ID: luena
# Processing record number: 603 #ID: taltal
# Processing record number: 604 #ID: ciawi
# Processing record number: 605 #ID: bend
# Processing record number: 606 #ID: areosa
# Processing record number: 607 #ID: lock+haven

# %%
#print(target_url)

# %%
data = name; cities = pd.DataFrame(data)
cities['temp_min'] = temp_min; 
cities['temp_max'] = temp_max; 
cities['humidity'] = hum; 
cities['latitude'] = lat; 
cities['longitude'] = lon; 
cities['clouds'] = cloud; 
cities['wind_speed'] = wind; 
cities['date_time'] = dt
#cities['date'] = time.ctime(cities['date_time'])
cities['country'] = country; 
cities = cities.rename(index=str, columns={0:"city"}); city_weather = cities

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather.to_csv(output_data_file, sep=',')

# %%
city_weather.head()
# Out:
#            city  temp_min  temp_max  humidity  latitude  longitude  clouds  \
# 0      Thompson   272.150   272.150        92     55.74     -97.86      90
# 1       Ushuaia   283.150   284.150        31    -54.81     -68.31      40
# 2  Richards Bay   298.936   298.936        54    -28.77      32.06      12
# 3        Avarua   295.150   295.150        94    -21.21    -159.78      90
# 4      Souillac   277.150   278.150        93     45.60      -0.60      90
#
#    wind_speed   date_time country
# 0        2.10  1540836000      CA
# 1        1.50  1540836000      AR
# 2        7.52  1540840027      ZA
# 3        8.20  1540836000      CK
# 4        3.10  1540837800      FR

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
x_axis1 = city_weather['latitude']; x_axis2 = city_weather['latitude']; x_axis3 = city_weather['latitude']; 
x_axis4 = city_weather['latitude']; y_axis1 = ((city_weather['temp_max'] - 273.15)*9/5 + 32); 
y_axis2 = city_weather['humidity']; y_axis3 = city_weather['clouds']; y_axis4 = city_weather['wind_speed']

# %%
lat_vs_temp = (plt.scatter(x_axis1, y_axis1, linewidth=1, edgecolors="black"), 
               plt.xlabel("Latitude"), plt.ylabel("Temperature(F)"), plt.title("City Latitude vs. Max Temperature 10/29/18"), 
               plt.grid(b=None, which='major', axis='both'), plt.savefig("output_images/lat_vs_temp.png"))
print("ANALYSIS")
print("---------------------------------------------------------------------------------------------------------------------")
print("Temperature peaks between -20 and 20 degrees latitude, supporting the notion that it gets hotter as one"
      " approaches the equator." 
      " There is also a clear negative trend in temperature as latitude increases between 20 and 80 degrees."
      " However, the opposite is true as latitude approaches 0 from -60: temperature actually increases,"
      " though the relationship is not as strong as that observed in the northern hemisphere."
      " One possible reason the relationship from latitude -60 to 0 is less pronounced is the presence of fewer data" 
      " points within that range."
      " The lack of data points in the southern hemisphere is most likely due to the lower number of cities"
      " located in the southern hemisphere."
      " The other three plots have no distinct trends, which implies no meaningful relationship between latitude and the" 
      " three other measured weather variables.")
# Out:
# <img src="data:image/png;base64,..." width="640">
# ANALYSIS
# ---------------------------------------------------------------------------------------------------------------------
# Temperature peaks between -20 and 20 degrees latitude, supporting the notion that it gets hotter as one approaches the equator. There is also a clear negative trend in temperature as latitude increases between 20 and 80 degrees. However, the opposite is true as latitude approaches 0 from -60: temperature actually increases, though the relationship is not as strong as that observed in the northern hemisphere. One possible reason the relationship from latitude -60 to 0 is less pronounced is the presence of fewer data points within that range. The lack of data points in the southern hemisphere is most likely due to the lower number of cities located in the southern hemisphere. The other three plots have no distinct trends, which implies no meaningful relationship between latitude and the three other measured weather variables.

# %%
lat_v_hum = (plt.scatter(x_axis2, y_axis2, linewidth=1, edgecolors="black"), plt.xlabel("Latitude"), plt.ylabel("Humidity (%)"),
             plt.title("City Latitude vs. Humidity 10/29/18"), plt.grid(b=None, which='major', axis='both'), 
             plt.savefig("output_images/lat_vs_hum.png"))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lat_vs_cloud = (plt.scatter(x_axis3, y_axis3, linewidth=1, edgecolors="black"), plt.xlabel("Latitude"),
                plt.ylabel("Cloud Cover (%)"), plt.title("City Latitude vs. Cloud Cover 10/29/18"), 
                plt.grid(b=None, which='major', axis='both'), plt.savefig("output_images/lat_vs_cloud.png"))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lat_vs_wind = (plt.scatter(x_axis4, y_axis4, linewidth=1, edgecolors="black"), plt.xlabel("Latitude"), 
               plt.ylabel("Wind Speed (mph)"), plt.title("City Latitude vs. Wind Speed 10/29/18"), 
               plt.grid(b=None, which='major', axis='both'), plt.savefig("output_images/lat_vs_wind.png"))
# Out:
# <img src="data:image/png;base64,..." width="640">
